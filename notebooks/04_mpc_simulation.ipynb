# %% [markdown]
# # Stage 4 MPC Simulation
#
# Replay a rolling-horizon MPC policy and compare its savings against the Stage 3 oracle.

# %%
import pandas as pd
from engine.addons.hvac import HVACAddon
from engine.core.ml.mpc import run_mpc

df = pd.read_parquet('data/cleaned_data.parquet')
addon = HVACAddon()
# mpc_result = run_mpc(...)
