# %% [markdown]
# # Stage 1: Data Pipeline Verification
#
# This notebook demonstrates the end-to-end data pipeline using the HVAC domain addon.

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
from engine.core.pipeline import run_pipeline
from engine.addons.hvac import HVACAddon

# %% [markdown]
# ## 1. Run Pipeline
#
# We load data from `data/example.csv` and inject the `HVACAddon`.

# %%
csv_path = '../data/example.csv'
addon = HVACAddon()

result = run_pipeline(csv_path, addon, timestep_minutes=15)
print("Addon ID:", result.addon_id)
print("Column Mapping:", result.column_mapping)

# %% [markdown]
# ## 2. Quality Report Summary

# %%
print(result.quality_report.summary())

# %% [markdown]
# ## 3. Data Preview & Derived Features

# %%
display(result.df.head(10))
display(result.df[['chw_delta_t', 'cooling_load_approx', 'system_kw_per_rt']].describe())
