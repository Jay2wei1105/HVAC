# %% [markdown]
# # Stage 3 Advisory
#
# Run Optuna advisory optimization with the q_demand safety constraint.

# %%
import pandas as pd
from engine.addons.hvac import HVACAddon
from engine.core.ml.optimizer import extract_control_variables, run_control_optimization, WEIGHT_PRESETS
from engine.core.types import SensorRole

bundle = pd.read_parquet('data/cleaned_data.parquet')
addon = HVACAddon()
# load your trained models before calling run_control_optimization
# result = run_control_optimization(...)
